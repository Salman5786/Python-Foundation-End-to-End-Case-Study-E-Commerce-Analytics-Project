# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Customers = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/CUSTOMERS.csv')
Customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix customer_city  customer_state
# 0                         14409      Adilabad  Andhra Pradesh
# 1                          9790         Adoni  Andhra Pradesh
# 2                          1151  Akkarampalle  Andhra Pradesh
# 3                          8775   Akkayapalle  Andhra Pradesh
# 4                         13056         Alwal  Andhra Pradesh
# ...                         ...           ...             ...
# 99436                      3937  Akkarampalle  Andhra Pradesh
# 99437                      6764     Nizamabad  Andhra Pradesh
# 99438                     60115   Dowleswaram  Andhra Pradesh
# 99439                     92120     Vepagunta  Andhra Pradesh
# 99440                      6703        Naspur  Andhra Pradesh
#
# [99441 rows x 5 columns]

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
Sellers = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/SELLERS.csv')
Sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13023
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#           seller_city    seller_state
# 0               Alwal  Andhra Pradesh
# 1               Alwal  Andhra Pradesh
# 2           Badepalle  Andhra Pradesh
# 3        Akkarampalle  Andhra Pradesh
# 4             Koratla  Andhra Pradesh
# ...               ...             ...
# 3090       Kalan Wali         Haryana
# 3091            Bopal         Gujarat
# 3092     Akkarampalle  Andhra Pradesh
# 3093  Ekambara kuppam  Andhra Pradesh
# 3094       Khongapani    Chhattisgarh
#
# [3095 rows x 4 columns]

# %%
Sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3038 non-null   object
#  3   seller_state            3038 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
Products = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/PRODUCTS.csv')
Products
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  Perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        Art
# 2      96bd76ec8810374ed1b65e291975717f             Sports_Leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       Baby
# 4      9dc1a7de274444849c219cff195d0b71                 Housewares
# ...                                 ...                        ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            Furniture_Decor
# 32947  bf4538d88321d0fd4412a93c974510e6  Construction_Tools_Lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             Bed_Bath_Table
# 32949  83808703fc0706a22e264b9d75f04a2e      Computers_Accessories
# 32950  106392145fca363410d287a815be6de4             Bed_Bath_Table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 0                  14.0
# 1                  20.0
# 2                  15.0
# 3                  26.0
# 4                  13.0
# ...                 ...
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0
#
# [32951 rows x 9 columns]

# %%
Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32328 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
Orders = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/ORDERS.csv')
Orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_approved_at  \
# 0        delivered          10/2/2017 10:56   10/2/2017 11:07
# 1        delivered          7/24/2018 20:41    7/26/2018 3:24
# 2        delivered            8/8/2018 8:38     8/8/2018 8:55
# 3        delivered         11/18/2017 19:28  11/18/2017 19:45
# 4        delivered          2/13/2018 21:18   2/13/2018 22:20
# ...            ...                      ...               ...
# 99436    delivered            3/9/2017 9:54     3/9/2017 9:54
# 99437    delivered           2/6/2018 12:58    2/6/2018 13:10
# 99438    delivered          8/27/2017 14:46   8/27/2017 15:04
# 99439    delivered           1/8/2018 21:28    1/8/2018 21:36
# 99440    delivered           3/8/2018 20:57    3/9/2018 11:20
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0                  10/4/2017 19:55              10/10/2017 21:25
# 1                  7/26/2018 14:31                8/7/2018 15:27
# 2                   8/8/2018 13:50               8/17/2018 18:06
# 3                 11/22/2017 13:39                12/2/2017 0:28
# 4                  2/14/2018 19:46               2/16/2018 18:17
# ...                            ...                           ...
# 99436              3/10/2017 11:18               3/17/2017 15:08
# 99437               2/7/2018 23:22               2/28/2018 17:37
# 99438              8/28/2017 20:52               9/21/2017 11:24
# 99439              1/12/2018 15:35               1/25/2018 23:32
# 99440               3/9/2018 22:11               3/16/2018 13:08
#
#       order_estimated_delivery_date
# 0                   10/18/2017 0:00
# 1                    8/13/2018 0:00
# 2                     9/4/2018 0:00
# 3                   12/15/2017 0:00
# 4                    2/26/2018 0:00
# ...                             ...
# 99436                3/28/2017 0:00
# 99437                 3/2/2018 0:00
# 99438                9/27/2017 0:00
# 99439                2/15/2018 0:00
# 99440                 4/3/2018 0:00
#
# [99441 rows x 8 columns]

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# fixing the datatypes of dates
Orders.order_purchase_timestamp = pd.to_datetime(Orders.order_purchase_timestamp, format = '%m/%d/%Y %H:%M')
Orders.order_approved_at = pd.to_datetime(Orders.order_approved_at, format = '%m/%d/%Y %H:%M')
Orders.order_delivered_carrier_date = pd.to_datetime(Orders.order_delivered_carrier_date, format = '%m/%d/%Y %H:%M')
Orders.order_delivered_customer_date = pd.to_datetime(Orders.order_delivered_customer_date, format = '%m/%d/%Y %H:%M')
Orders.order_estimated_delivery_date = pd.to_datetime(Orders.order_estimated_delivery_date, format = '%m/%d/%Y %H:%M')

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
Order_Items = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/ORDER_ITEMS.csv')
Order_Items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#        shipping_limit_date   price  freight_value
# 0           9/19/2017 9:45   58.90          13.29
# 1           5/3/2017 11:05  239.90          19.93
# 2          1/18/2018 14:48  199.00          17.87
# 3          8/15/2018 10:10   12.99          12.79
# 4          2/13/2017 13:57  199.90          18.14
# ...                    ...     ...            ...
# 112645       5/2/2018 4:11  299.99          43.41
# 112646      7/20/2018 4:31  350.00          36.53
# 112647    10/30/2017 17:14   99.90          16.95
# 112648      8/21/2017 0:04   55.99           8.72
# 112649     6/12/2018 17:10   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
Order_Items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# fixing the datatypes of dates
Order_Items.shipping_limit_date = pd.to_datetime(Order_Items.shipping_limit_date, format = '%m/%d/%Y %H:%M')

# %%
Order_Items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
Order_Payments = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/ORDER_PAYMENTS.csv')
Order_Payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1          UPI
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1          UPI
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
Order_Payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
Order_Review_Ratings = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/ORDER_REVIEW_RATINGS.csv')
Order_Review_Ratings
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_creation_date review_answer_timestamp
# 0                 4       1/18/2018 0:00         1/18/2018 21:46
# 1                 5       3/10/2018 0:00          3/11/2018 3:05
# 2                 5       2/17/2018 0:00         2/18/2018 14:36
# 3                 5       4/21/2017 0:00         4/21/2017 22:02
# 4                 5        3/1/2018 0:00          3/2/2018 10:26
# ...             ...                  ...                     ...
# 99995             5       12/9/2017 0:00        12/11/2017 20:06
# 99996             5       3/22/2018 0:00          3/23/2018 9:10
# 99997             4        7/1/2018 0:00          7/2/2018 12:59
# 99998             1      12/15/2017 0:00         12/16/2017 1:29
# 99999             1        7/3/2017 0:00          7/3/2017 21:01
#
# [100000 rows x 5 columns]

# %%
Order_Review_Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_creation_date     100000 non-null  object
#  4   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# fixing the datatypes of dates
Order_Review_Ratings.review_creation_date = pd.to_datetime(Order_Review_Ratings.review_creation_date, format = '%m/%d/%Y %H:%M')
Order_Review_Ratings.review_answer_timestamp = pd.to_datetime(Order_Review_Ratings.review_answer_timestamp, format = '%m/%d/%Y %H:%M')

# %%
Order_Review_Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_creation_date     100000 non-null  datetime64[ns]
#  4   review_answer_timestamp  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 3.8+ MB

# %%
Geo_Location = pd.read_csv('D:/Projects/Python/Python Foundation End to End Case Study E-Commerce Analytics Project/GEO_LOCATION.csv')
Geo_Location
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                             1037       -23.545621       -46.639292
# 1                             1046       -23.546081       -46.644820
# 2                             1041       -23.544392       -46.639499
# 3                             1035       -23.541578       -46.641607
# 4                             1012       -23.547762       -46.635361
# ...                            ...              ...              ...
# 19010                        99955       -28.107588       -52.144019
# 19011                        99970       -28.345143       -51.876926
# 19012                        99910       -27.863500       -52.084760
# 19013                        99920       -27.858716       -52.300403
# 19014                        99952       -28.160371       -51.936922
#
#       geolocation_city geolocation_state
# 0         Akkarampalle    Andhra Pradesh
# 1         Akkarampalle    Andhra Pradesh
# 2         Akkarampalle    Andhra Pradesh
# 3         Akkarampalle    Andhra Pradesh
# 4         Akkarampalle    Andhra Pradesh
# ...                ...               ...
# 19010        Ghaziabad     Uttar Pradesh
# 19011      Vadugapatti        Tamil Nadu
# 19012     Akkarampalle    Andhra Pradesh
# 19013          Kolkata       West Bengal
# 19014     Akkarampalle    Andhra Pradesh
#
# [19015 rows x 5 columns]

# %%
Geo_Location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19015 entries, 0 to 19014
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat              19015 non-null  float64
#  2   geolocation_lng              19015 non-null  float64
#  3   geolocation_city             19015 non-null  object
#  4   geolocation_state            19015 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 742.9+ KB

# %% [markdown]
# ## 1. Perform Detailed exploratory analysis

# %% [markdown]
# ### a. Define & calculate high level metrics like (Total Revenue, Total quantity, Total products, Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %%
# Total Revenue
Order_Payments.payment_value.sum()
# Out:
# 16008872.12

# %%
# Total quantity
Order_Items.shape[0]
# Out:
# 112650

# %%
# Total products
Products.product_id.nunique()
# Out:
# 32951

# %%
# Total categories
Products.product_category_name.nunique()
# Out:
# 71

# %%
# Total sellers
Sellers.seller_id.nunique()
# Out:
# 3095

# %%
# Total locations
Geo_Location.geolocation_zip_code_prefix.nunique()
# Out:
# 19015

# %%
# Total payment methods
Order_Payments.payment_type.nunique()
# Out:
# 5

# %% [markdown]
# ### b. Understanding how many new customers acquired every month

# %%
cust_order = pd.merge(left = Customers, right = Orders, how = 'inner', on = 'customer_id').sort_values(by = 'order_purchase_timestamp').reset_index(drop = True)
cust_order.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  08c5351a6aca1c1589a38f244edeee9d  b7d76e111c89f7ebf14761390f0f7d17
# 1  683c54fc24d40ee9f8a6fc179fd9856c  4854e9b3feff728c13ee5fc7d1547e92
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     69309        Dholka         Gujarat
# 1                     99025          Tuni  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047      shipped      2016-09-04 21:15:00
# 1  e5fa5a7210941f7d56d0208e4e071d35     canceled      2016-09-05 00:15:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2016-10-07 13:18:00          2016-10-18 13:14:00
# 1 2016-10-07 13:17:00                          NaT
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0                           NaT                    2016-10-20
# 1                           NaT                    2016-10-28

# %%
cust = cust_order['customer_unique_id'].duplicated(keep = 'last')
new_cust = cust_order[cust].reset_index(drop = True)
new_cust['Month'] = new_cust.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%m'))
new_cust['Year'] = new_cust.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%Y'))
new_cust.loc[:, ['Year', 'Month', 'customer_unique_id']].groupby(['Year', 'Month']).count()
# Out:
#             customer_unique_id
# Year Month
# 2016 10                     12
#      12                      1
# 2017 01                     68
#      02                     76
#      03                    133
#      04                    115
#      05                    213
#      06                    185
#      07                    206
#      08                    228
#      09                    211
#      10                    191
#      11                    270
#      12                    174
# 2018 01                    241
#      02                    277
#      03                    196
#      04                    155
#      05                    130
#      06                     86
#      07                    113
#      08                     61
#      09                      3

# %% [markdown]
# ### c. Understand the retention of customers on month on month basis

# %%
exist_cust = cust_order[~cust].reset_index(drop = True)
exist_cust['Month'] = exist_cust.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%m'))
exist_cust['Year'] = exist_cust.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%Y'))
exist_cust.loc[:, ['Year', 'Month', 'customer_unique_id']].groupby(['Year', 'Month']).count()
# Out:
#             customer_unique_id
# Year Month
# 2016 09                      4
#      10                    312
# 2017 01                    732
#      02                   1704
#      03                   2549
#      04                   2289
#      05                   3487
#      06                   3060
#      07                   3820
#      08                   4103
#      09                   4074
#      10                   4440
#      11                   7274
#      12                   5499
# 2018 01                   7028
#      02                   6451
#      03                   7015
#      04                   6784
#      05                   6743
#      06                   6081
#      07                   6179
#      08                   6451
#      09                     13
#      10                      4

# %% [markdown]
# ### d. How the revenues from existing/new customers on month on month basis

# %%
cust_order_payments = pd.merge(left = cust_order, right = Order_Payments, how = 'inner', on = 'order_id').sort_values(by = 'order_purchase_timestamp').reset_index(drop = True)
cust_order_payments.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  08c5351a6aca1c1589a38f244edeee9d  b7d76e111c89f7ebf14761390f0f7d17
# 1  683c54fc24d40ee9f8a6fc179fd9856c  4854e9b3feff728c13ee5fc7d1547e92
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     69309        Dholka         Gujarat
# 1                     99025          Tuni  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  2e7a8482f6fb09756ca50c10d7bfc047      shipped      2016-09-04 21:15:00
# 1  e5fa5a7210941f7d56d0208e4e071d35     canceled      2016-09-05 00:15:00
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2016-10-07 13:18:00          2016-10-18 13:14:00
# 1 2016-10-07 13:17:00                          NaT
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0                           NaT                    2016-10-20
# 1                           NaT                    2016-10-28
#
#    payment_sequential payment_type  payment_installments  payment_value
# 0                   1  credit_card                     1         136.23
# 1                   1  credit_card                     3          75.06

# %% [markdown]
# #### for existing customers

# %%
cust_revenue = cust_order_payments['customer_unique_id'].duplicated(keep = 'last')
exist_cust_revenue = cust_order_payments[~cust_revenue].reset_index(drop = True)
exist_cust_revenue['Month'] = exist_cust_revenue.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%m'))
exist_cust_revenue['Year'] = exist_cust_revenue.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%Y'))
exist_cust_revenue.loc[:, ['Year', 'Month', 'payment_value']].groupby(['Year', 'Month']).sum()
# Out:
#             payment_value
# Year Month
# 2016 09            252.24
#      10          56990.68
# 2017 01         128334.06
#      02         276066.01
#      03         420078.95
#      04         388912.63
#      05         548030.27
#      06         477815.63
#      07         551945.60
#      08         632595.51
#      09         680376.28
#      10         735017.40
#      11        1137268.39
#      12         844674.54
# 2018 01        1061477.82
#      02         936110.41
#      03        1116031.16
#      04        1120134.15
#      05        1117592.46
#      06         994694.96
#      07        1026325.59
#      08         992473.77
#      09           4062.78
#      10            589.67

# %% [markdown]
# #### for new customers

# %%
new_cust_revenue = cust_order_payments[cust_revenue].reset_index(drop = True)
new_cust_revenue['Month'] = new_cust_revenue.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%m'))
new_cust_revenue['Year'] = new_cust_revenue.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%Y'))
new_cust_revenue.loc[:, ['Year', 'Month', 'payment_value']].groupby(['Year', 'Month']).sum()
# Out:
#             payment_value
# Year Month
# 2016 10           2099.80
#      12             19.62
# 2017 01          10153.98
#      02          15842.00
#      03          29784.65
#      04          28875.40
#      05          44888.55
#      06          33460.75
#      07          40437.32
#      08          41800.81
#      09          47386.17
#      10          44660.48
#      11          57614.41
#      12          33726.94
# 2018 01          53526.36
#      02          56352.93
#      03          43620.96
#      04          40651.33
#      05          36389.69
#      06          29185.54
#      07          40215.16
#      08          29951.55
#      09            376.76

# %% [markdown]
# ### e. Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, channel, payment method etc…

# %%
cust_order_review_ratings = pd.merge(left = cust_order, right = Order_Review_Ratings, how = 'left', on = 'order_id')
cust_order_order_payments = pd.merge(left = cust_order_review_ratings, right = Order_Payments, how = 'left', on = 'order_id')
cust_order_order_items = pd.merge(left = cust_order_order_payments, right = Order_Items, how = 'left', on = 'order_id')
cust_order_products = pd.merge(left = cust_order_order_items, right = Products, how = 'left', on = 'product_id')
cust_order_geo_location = pd.merge(left = cust_order_products, right = Geo_Location, how = 'left', left_on = 'customer_zip_code_prefix', right_on = 'geolocation_zip_code_prefix')
cust_order_final = pd.merge(left = cust_order_geo_location, right = Sellers, how = 'left', left_on = 'geolocation_zip_code_prefix', right_on = 'seller_zip_code_prefix')
cust_order_final['Month'] = cust_order_final.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%m'))
cust_order_final['Year'] = cust_order_final.order_purchase_timestamp.apply(lambda x : pd.Timestamp.strftime(x, format = '%Y'))
cust_order_final
# Out:
#                              customer_id                customer_unique_id  \
# 0       08c5351a6aca1c1589a38f244edeee9d  b7d76e111c89f7ebf14761390f0f7d17
# 1       08c5351a6aca1c1589a38f244edeee9d  b7d76e111c89f7ebf14761390f0f7d17
# 2       683c54fc24d40ee9f8a6fc179fd9856c  4854e9b3feff728c13ee5fc7d1547e92
# 3       622e13439d6b5a0b486c435618b2679e  009b0127b727ab0ba422f6d9604487c7
# 4       86dc2ffce2dfff336de2f386a786e574  830d5b7aaa3b6f1e9ad63703bec97d23
# ...                                  ...                               ...
# 140136  bf6181a85bbb4115736c0a8db1a53be3  634420a0ea42302205032ed44ac7fccc
# 140137  4c2ec60c29d10c34bd49cb88aa85cfc4  af5454198a97379394cacf676e1e96cb
# 140138  4c2ec60c29d10c34bd49cb88aa85cfc4  af5454198a97379394cacf676e1e96cb
# 140139  856336203359aa6a61bf3826f7d84c49  262e1f1e26e92e86375f86840b4ffd63
# 140140  a4b417188addbc05b26b72d5e44837a1  87ab9fec999db8bd5774917de3cdf01c
#
#         customer_zip_code_prefix customer_city  customer_state  \
# 0                          69309        Dholka         Gujarat
# 1                          69309        Dholka         Gujarat
# 2                          99025          Tuni  Andhra Pradesh
# 3                          12244       Bobbili  Andhra Pradesh
# 4                          14600      Kandukur  Andhra Pradesh
# ...                          ...           ...             ...
# 140136                     27175    Tallapalle  Andhra Pradesh
# 140137                     11900      Sukhrali         Haryana
# 140138                     11900      Sukhrali         Haryana
# 140139                     64600   Mirpur Turk           Delhi
# 140140                     18077  Bade Bacheli    Chhattisgarh
#
#                                 order_id order_status  \
# 0       2e7a8482f6fb09756ca50c10d7bfc047      shipped
# 1       2e7a8482f6fb09756ca50c10d7bfc047      shipped
# 2       e5fa5a7210941f7d56d0208e4e071d35     canceled
# 3       809a282bbd5dbcabb6f2f724fca862ec     canceled
# 4       bfbd0f9bdef84302105ad712db648a6c    delivered
# ...                                  ...          ...
# 140136  616fa7d4871b87832197b2a137a115d2     canceled
# 140137  a2ac6dad85cf8af5b0afb510a240fe8c     canceled
# 140138  a2ac6dad85cf8af5b0afb510a240fe8c     canceled
# 140139  b059ee4de278302d550a3035c4cdb740     canceled
# 140140  10a045cdf6a5650c21e9cfeb60384c16     canceled
#
#        order_purchase_timestamp   order_approved_at  \
# 0           2016-09-04 21:15:00 2016-10-07 13:18:00
# 1           2016-09-04 21:15:00 2016-10-07 13:18:00
# 2           2016-09-05 00:15:00 2016-10-07 13:17:00
# 3           2016-09-13 15:24:00 2016-10-07 13:16:00
# 4           2016-09-15 12:16:00 2016-09-15 12:16:00
# ...                         ...                 ...
# 140136      2018-10-01 15:30:00                 NaT
# 140137      2018-10-03 18:55:00                 NaT
# 140138      2018-10-03 18:55:00                 NaT
# 140139      2018-10-16 20:16:00                 NaT
# 140140      2018-10-17 17:30:00                 NaT
#
#        order_delivered_carrier_date  ... geolocation_lat geolocation_lng  \
# 0               2016-10-18 13:14:00  ...        2.812997      -60.695264
# 1               2016-10-18 13:14:00  ...        2.812997      -60.695264
# 2                               NaT  ...      -28.261098      -52.407671
# 3                               NaT  ...      -23.204901      -45.950860
# 4               2016-11-07 17:11:00  ...      -20.581177      -47.858931
# ...                             ...  ...             ...             ...
# 140136                          NaT  ...      -22.609470      -43.912345
# 140137                          NaT  ...      -24.492030      -47.834131
# 140138                          NaT  ...      -24.492030      -47.834131
# 140139                          NaT  ...       -7.077400      -41.470740
# 140140                          NaT  ...      -23.450594      -47.475700
#
#        geolocation_city  geolocation_state                       seller_id_y  \
# 0                Dholka            Gujarat                               NaN
# 1                Dholka            Gujarat                               NaN
# 2                  Tuni     Andhra Pradesh                               NaN
# 3               Bobbili     Andhra Pradesh                               NaN
# 4              Kandukur     Andhra Pradesh  6d803cb79cc31c41c4c789a75933b3c7
# ...                 ...                ...                               ...
# 140136       Tallapalle     Andhra Pradesh                               NaN
# 140137         Sukhrali            Haryana  c66dccfb3f109511246da627dd5a2498
# 140138         Sukhrali            Haryana  2199e7fe213c16213bf5d6a7eadc9a5d
# 140139      Mirpur Turk              Delhi                               NaN
# 140140     Bade Bacheli       Chhattisgarh                               NaN
#
#        seller_zip_code_prefix  seller_city    seller_state  Month  Year
# 0                         NaN          NaN             NaN     09  2016
# 1                         NaN          NaN             NaN     09  2016
# 2                         NaN          NaN             NaN     09  2016
# 3                         NaN          NaN             NaN     09  2016
# 4                     14600.0     Kandukur  Andhra Pradesh     09  2016
# ...                       ...          ...             ...    ...   ...
# 140136                    NaN          NaN             NaN     10  2018
# 140137                11900.0     Sukhrali         Haryana     10  2018
# 140138                11900.0     Sukhrali         Haryana     10  2018
# 140139                    NaN          NaN             NaN     10  2018
# 140140                    NaN          NaN             NaN     10  2018
#
# [140141 rows x 45 columns]

# %% [markdown]
# #### sales by category

# %%
cust_order_final.loc[:, ['product_category_name', 'price']].groupby('product_category_name').sum().sort_values(by = 'price', ascending = False).plot(kind = 'bar', figsize = (24, 12))
plt.show()

# %% [markdown]
# #### sales by location

# %%
cust_order_final.loc[:, ['geolocation_state', 'price']].groupby('geolocation_state').sum().sort_values(by = 'price', ascending = False).plot(kind = 'bar', figsize = (12, 6))
plt.show()

# %% [markdown]
# #### sales by month

# %%
cust_order_final.loc[:, ['Month', 'price']].groupby('Month').sum().sort_values(by = 'price', ascending = False).plot(kind = 'bar', figsize = (12, 6))
plt.show()

# %% [markdown]
# #### sales by week

# %%
cust_order_final.loc[:, ['price']].groupby(cust_order_final.order_purchase_timestamp.dt.isocalendar().week).sum().plot(kind = 'line', figsize = (16, 8))
plt.show()

# %% [markdown]
# #### sales by day

# %%
cust_order_final.loc[:, ['price']].groupby(cust_order_final.order_purchase_timestamp.dt.isocalendar().day).sum().plot(kind = 'line', figsize = (16, 8))
plt.show()

# %% [markdown]
# #### sales by time

# %%
cust_order_final.loc[:, ['order_purchase_timestamp', 'price']].groupby('order_purchase_timestamp').sum().plot(kind = 'line', figsize = (24, 12))
plt.show()

# %% [markdown]
# #### sales by payment method

# %%
cust_order_final.loc[:, ['payment_type', 'price']].groupby('payment_type').sum().sort_values(by = 'price', ascending = False).plot(kind = 'bar', figsize = (10, 5))
plt.show()

# %% [markdown]
# ### f. Popular Products by month, seller, state, category.

# %% [markdown]
# #### popular products by month

# %%
cust_order_final.loc[:, ['product_id', 'Month', 'order_id']].groupby(['product_id', 'Month']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                         order_id
# product_id                       Month
# aca2eb7d00ea1a7b8ebd4e68314663af 01          142
# 11250b0d4b709fee92441c5f34122aed 02          127
# 53b36df67ebb7c41585e8d54d6772e08 05          126
# 99a4788cb24856965c36a24e339b6058 05          122
# 53b36df67ebb7c41585e8d54d6772e08 04          108
# ...                                          ...
# 694e58e56c74114ee0628c25f3f26f8c 07            1
#                                  10            1
# 694ef7517a535b054fddea9154d3e627 09            1
# 694f7daacd749d7bde487e0f9675c5b8 02            1
# fffe9eeff12fcbd74a2f2b007dde0c58 05            1
#
# [60796 rows x 1 columns]

# %% [markdown]
# #### popular products by seller

# %%
cust_order_final.loc[:, ['product_id', 'seller_id_x', 'order_id']].groupby(['product_id', 'seller_id_x']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                                                    order_id
# product_id                       seller_id_x
# aca2eb7d00ea1a7b8ebd4e68314663af 955fee9216a65b617aa5c0531780ce60       631
# 99a4788cb24856965c36a24e339b6058 4a3ca9315b744ce9f8e9374361493884       623
# 422879e10f46682990de24d770e7f83d 1f50f920176fa81dab994f9023523100       574
# 389d119b48cf3043d311335e499d9c6b 1f50f920176fa81dab994f9023523100       480
# 368c6c730842d78016ad823897a372db 1f50f920176fa81dab994f9023523100       450
# ...                                                                     ...
# 70ecfc40193a5327e6921986e6484fab 96493fab2fbb13a14d0c0e8772eef5c3         1
# 70e9f13542ae210a1e09bae121496075 de23c3b98a88888289c6f5cc1209054a         1
# 70e0d082134b563e2977cf5f268ad3f9 1da3aeb70d7989d1e6d9b0e887f97c23         1
# 70de7f927d3615d94199abf14387491f b372ee768ed69e46ca8cdbd267aa7a38         1
# fffe9eeff12fcbd74a2f2b007dde0c58 7299e27ed73d2ad986de7f7c77d919fa         1
#
# [34448 rows x 1 columns]

# %% [markdown]
# #### popular products by state

# %%
cust_order_final.loc[:, ['product_id', 'geolocation_state', 'order_id']].groupby(['product_id', 'geolocation_state']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                                     order_id
# product_id                       geolocation_state
# aca2eb7d00ea1a7b8ebd4e68314663af Andhra Pradesh          423
# 99a4788cb24856965c36a24e339b6058 Andhra Pradesh          408
# 422879e10f46682990de24d770e7f83d Andhra Pradesh          351
# 389d119b48cf3043d311335e499d9c6b Andhra Pradesh          280
# 53b36df67ebb7c41585e8d54d6772e08 Andhra Pradesh          279
# ...                                                      ...
# 68b8e52885d1c878e362c8a4d323747b Maharashtra               1
# 68b92c941d4052c59ba87c2b2824bfa8 Chhattisgarh              1
# 68b9af8698585855f2503727e150d453 Andhra Pradesh            1
# 68baff1f2dbcb2df8581897b10150905 Andhra Pradesh            1
# fffe9eeff12fcbd74a2f2b007dde0c58 Gujarat                   1
#
# [54172 rows x 1 columns]

# %% [markdown]
# #### popular products by category

# %%
cust_order_final.loc[:, ['product_id', 'product_category_name', 'order_id']].groupby(['product_id', 'product_category_name']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                                         order_id
# product_id                       product_category_name
# aca2eb7d00ea1a7b8ebd4e68314663af Furniture_Decor             631
# 99a4788cb24856965c36a24e339b6058 Bed_Bath_Table              629
# 422879e10f46682990de24d770e7f83d Garden_Tools                574
# 389d119b48cf3043d311335e499d9c6b Garden_Tools                480
# 368c6c730842d78016ad823897a372db Garden_Tools                450
# ...                                                          ...
# 71f5cad782714ec5d61a1bfa34543403 Consoles_Games                1
# 71f0bc096460c175e49cb3826bc8761a Furniture_Decor               1
# 71edb37d9bd2542f8df816d01a86af3a Sports_Leisure                1
# 71eb412501d048544056785e00b1889a Bed_Bath_Table                1
# fffe9eeff12fcbd74a2f2b007dde0c58 Toys                          1
#
# [32328 rows x 1 columns]

# %% [markdown]
# ### g. Popular categories by state, month

# %% [markdown]
# #### popular categories by state

# %%
cust_order_final.loc[:, ['product_category_name', 'geolocation_state', 'order_id']].groupby(['product_category_name', 'geolocation_state']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                          order_id
# product_category_name geolocation_state
# Bed_Bath_Table        Andhra Pradesh         9506
# Health_Beauty         Andhra Pradesh         7534
# Furniture_Decor       Andhra Pradesh         6919
# Sports_Leisure        Andhra Pradesh         6863
# Computers_Accessories Andhra Pradesh         6338
# ...                                           ...
# Sports_Leisure        Goa                       1
# Books_Imported        Maharashtra               1
# Furniture_Bedroom     Arunachal Pradesh         1
# Housewares            Goa                       1
# Furniture_Bedroom     Haryana                   1
#
# [1063 rows x 1 columns]

# %% [markdown]
# #### popular categories by month

# %%
cust_order_final.loc[:, ['product_category_name', 'Month', 'order_id']].groupby(['product_category_name', 'Month']).count().sort_values(by = 'order_id', ascending = False)
# Out:
#                                  order_id
# product_category_name     Month
# Bed_Bath_Table            07         1558
#                           05         1488
#                           08         1468
#                           06         1450
# Computers_Accessories     02         1432
# ...                                   ...
# Construction_Tools_Lights 09            1
# Fashio_Female_Clothing    10            1
# Music                     10            1
# Diapers_And_Hygiene       10            1
# Cds_Dvds_Musicals         10            1
#
# [797 rows x 1 columns]

# %% [markdown]
# ### h. List top 10 most expensive products sorted by price

# %%
cust_order_final.loc[:, ['product_id', 'price']].sort_values(by = 'price', ascending = False).head(10)
# Out:
#                               product_id    price
# 2978    489ae2aa008f021502940f251d4cce7f  6735.00
# 129251  69c590f7ffc7bf8db97190b6cb6ed62e  6729.00
# 15460   1bdf5e6731585cf01aa8169c7028d6ad  6499.00
# 8071    a6492cc69376c469ab6f61d8f44de961  4799.00
# 9741    c3ed642d592594bb648ff4a04cee2747  4690.00
# 120235  259037a6a41845e455183f89c5035f18  4590.00
# 132528  a1beef8f3992dbd4cd8726796aa69c53  4399.87
# 93831   6cdf8fc1d741c76586d8b6b15e9eef30  4099.99
# 130231  dd113cb02b2af9c8e5787e8f1f0722f6  4059.00
# 6455    6902c1962dd19d540807d0ab8fade5c6  3999.90

# %% [markdown]
# ## 2. Performing Customers/sellers Segmentation

# %% [markdown]
# ### a. Divide the customers into groups based on the revenue generated

# %%
cust_order_final['customer_revenue_group'] = pd.qcut(cust_order_final.payment_value, 3, labels = ['Low', 'Medium', 'High'])
cust_order_final.customer_revenue_group.value_counts()
# Out:
# Medium    46716
# Low       46713
# High      46709
# Name: customer_revenue_group, dtype: int64

# %% [markdown]
# ### b. Divide the sellers into groups based on the revenue generated

# %%
cust_order_final['seller_revenue_group'] = pd.qcut(cust_order_final.price, 3, labels = ['Cheap', 'Budget_friendly', 'Expensive'])
cust_order_final.seller_revenue_group.value_counts()
# Out:
# Cheap              47064
# Expensive          46126
# Budget_friendly    45940
# Name: seller_revenue_group, dtype: int64

# %% [markdown]
# ## 3. Cross-Selling (Which products are selling together)

# %%
cross_selling = cust_order_final.loc[:, ['order_id', 'product_category_name']].groupby('order_id').agg({'product_category_name' : list}).assign(count = lambda x : x['product_category_name'].str.len())
cross_selling[cross_selling['count'] > 1].sort_values(by = 'count', ascending = False)
# Out:
#                                                               product_category_name  \
# order_id
# 465c2e1bee4561cb39e0db8c5993aafc  [Agro_Industry_And_Commerce, Agro_Industry_And...
# cf287f639abd10b1630574c4a065d4f1  [Stationery, Stationery, Stationery, Stationer...
# 61edec4c7086a5383dc4f5e6fca69e9b  [Sports_Leisure, Sports_Leisure, Sports_Leisur...
# 3241baf723e29f140a6ff9082b7f9aca  [Computers_Accessories, Computers_Accessories,...
# 1b15974a0141d54e36626dca3fdc731a  [Computers_Accessories, Computers_Accessories,...
# ...                                                                             ...
# 66eb2e45baf0a88a06f8d17a1e756ff6                 [Furniture_Decor, Furniture_Decor]
# 66ece7c73f4550ac89c08ffa53e85dc2                     [Health_Beauty, Health_Beauty]
# 66ed65fb801b44984e7a79b2d0496772         [Musical_Instruments, Musical_Instruments]
# 66f3359b47e8264aac9b1ab1f7bec4d3                           [Cool_Stuff, Cool_Stuff]
# 80850824446cd379f755548b967c61b9                   [Books_Imported, Books_Imported]
#
#                                   count
# order_id
# 465c2e1bee4561cb39e0db8c5993aafc    120
# cf287f639abd10b1630574c4a065d4f1    108
# 61edec4c7086a5383dc4f5e6fca69e9b     98
# 3241baf723e29f140a6ff9082b7f9aca     98
# 1b15974a0141d54e36626dca3fdc731a     80
# ...                                 ...
# 66eb2e45baf0a88a06f8d17a1e756ff6      2
# 66ece7c73f4550ac89c08ffa53e85dc2      2
# 66ed65fb801b44984e7a79b2d0496772      2
# 66f3359b47e8264aac9b1ab1f7bec4d3      2
# 80850824446cd379f755548b967c61b9      2
#
# [21010 rows x 2 columns]

# %% [markdown]
# ## 4. Payment Behaviour

# %% [markdown]
# ### a. How customers are paying?

# %%
cust_order_final.payment_type.dropna().unique()
# Out:
# array(['credit_card', 'UPI', 'debit_card', 'voucher', 'not_defined'],
#       dtype=object)

# %% [markdown]
# ### b. Which payment channels are used by most customers?

# %%
cust_order_final.payment_type.value_counts().head(1)
# Out:
# credit_card    102746
# Name: payment_type, dtype: int64

# %% [markdown]
# ## 5. Customer satisfaction towards category & product

# %% [markdown]
# ### a. Which categories (top 10) are maximum rated & minimum rated?

# %% [markdown]
# #### maximum rated categories

# %%
cust_order_final.loc[:, ['product_category_name', 'review_score']].groupby('product_category_name').mean().sort_values(by = 'review_score', ascending = False).head(10)
# Out:
#                                        review_score
# product_category_name
# Books_Imported                             4.664000
# Cds_Dvds_Musicals                          4.600000
# Fashion_Childrens_Clothes                  4.500000
# Small_Appliances_Home_Oven_And_Coffee      4.450000
# Books_General_Interest                     4.444126
# Costruction_Tools_Tools                    4.416000
# Food_Drink                                 4.398230
# Books_Technical                            4.388704
# Cine_Photo                                 4.336957
# Flowers                                    4.333333

# %% [markdown]
# #### minimum rated categories

# %%
cust_order_final.loc[:, ['product_category_name', 'review_score']].groupby('product_category_name').mean().sort_values(by = 'review_score', ascending = False).tail(10)
# Out:
#                                    review_score
# product_category_name
# Furniture_Mattress_And_Upholstery      3.800000
# Furniture_Living_Room                  3.763754
# Fixed_Telephony                        3.723473
# Fashio_Female_Clothing                 3.696429
# Office_Furniture                       3.534851
# La_Cuisine                             3.500000
# Fashion_Male_Clothing                  3.469565
# Diapers_And_Hygiene                    3.304348
# Home_Comfort_2                         3.300000
# Security_And_Services                  2.500000

# %% [markdown]
# ### b. Which products (top10) are maximum rated & minimum rated?

# %% [markdown]
# #### maximum rated products

# %%
cust_order_final.loc[:, ['product_id', 'review_score']].groupby('product_id').mean().sort_values(by = 'review_score', ascending = False).head(10)
# Out:
#                                   review_score
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           5.0
# 86743ff92eee3d16b7df59cddd583b8c           5.0
# 868ceb027ab706a4dee42e2220006b85           5.0
# 868969d3a93aeeab7bfcd4fc3d3d65de           5.0
# 868766ed2172644fdd977d6bd395a107           5.0
# 8684bd8f93b4f4038d07188a23811e93           5.0
# 867c96d2bb67aba6500a4c509cf76072           5.0
# 867b820367ec206b38a357f2c12454b7           5.0
# 867901d7e8488fb97f1fb538c09d476e           5.0
# 865bfa00c1dad8f4146d3c2765f051ca           5.0

# %% [markdown]
# #### minimum rated products

# %%
cust_order_final.loc[:, ['product_id', 'review_score']].groupby('product_id').mean().sort_values(by = 'review_score', ascending = False).tail(10)
# Out:
#                                   review_score
# product_id
# 37c599910c4de68c0bf1af0c6428ab1c           1.0
# 856af50654f3ba4a223ae9b5b8d243c0           1.0
# eae50b5c9a18c296b7fa904cf04406a5           1.0
# 7933eeb8cf79ae899bfac71c0edb076d           1.0
# 10a3a969b9e7d03b0dc2384ebbcad6ef           1.0
# 10a6596b3224c408ee46c8aaaa2977cd           1.0
# 602bd303d85e0e535a0767b9f1d85f91           1.0
# 859c4a81490e9402bac13f62672482d1           1.0
# 093cd981b714bcdff182b427d87fc8fc           1.0
# 4bae12e58c9b828e1302a2cad437b80a           1.0

# %% [markdown]
# ### c. Average rating by location, seller, product, category, month etc.

# %% [markdown]
# #### average rating by location

# %%
cust_order_final.loc[:, ['geolocation_state', 'review_score']].groupby('geolocation_state').mean().sort_values(by = 'review_score', ascending = False)
# Out:
#                    review_score
# geolocation_state
# Goa                    4.777778
# Punjab                 4.154211
# Rajasthan              4.148678
# Uttar Pradesh          4.110911
# Tamil Nadu             4.103523
# Haryana                4.103113
# Orissa                 4.088589
# Maharashtra            4.075871
# Gujarat                4.066957
# Delhi                  4.035018
# Jammu & Kashmir        4.031646
# Kerala                 4.031250
# Chhattisgarh           4.020367
# Karnataka              4.011113
# Arunachal Pradesh      4.008766
# Andhra Pradesh         3.983317
# Madhya Pradesh         3.980731
# West Bengal            3.938303
# Himachal Pradesh       3.928144
# Uttaranchal            3.669811

# %% [markdown]
# #### average rating by seller

# %%
cust_order_final.loc[:, ['seller_id_x', 'review_score']].groupby('seller_id_x').mean().sort_values(by = 'review_score', ascending = False)
# Out:
#                                   review_score
# seller_id_x
# 32e5635e63cb374eb63afdd242fb6134           5.0
# 41958cbd3335433c8740300e8cd600d5           5.0
# d7827b2af99326a03b0ed9c7a24db0d3           5.0
# eb1bf309f4f6af9a97e9ddac3fdbeabe           5.0
# a56a8043ebf66e42119618fb8cf232c6           5.0
# ...                                        ...
# 1444c08e64d55fb3c25f0f09c07ffcf2           1.0
# ad738d3fcf42655ed15c4960b7b6c601           1.0
# e46bc031f2c5bae4ccb40bb90712e9b4           1.0
# 7e3dde9ffba72d5340f9aaf09b4424be           1.0
# f524ad65d7e0f1daab730ef2d2e86196           1.0
#
# [3095 rows x 1 columns]

# %% [markdown]
# #### average rating by product

# %%
cust_order_final.loc[:, ['product_id', 'review_score']].groupby('product_id').mean().sort_values(by = 'review_score', ascending = False)
# Out:
#                                   review_score
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           5.0
# 86743ff92eee3d16b7df59cddd583b8c           5.0
# 868ceb027ab706a4dee42e2220006b85           5.0
# 868969d3a93aeeab7bfcd4fc3d3d65de           5.0
# 868766ed2172644fdd977d6bd395a107           5.0
# ...                                        ...
# 10a6596b3224c408ee46c8aaaa2977cd           1.0
# 602bd303d85e0e535a0767b9f1d85f91           1.0
# 859c4a81490e9402bac13f62672482d1           1.0
# 093cd981b714bcdff182b427d87fc8fc           1.0
# 4bae12e58c9b828e1302a2cad437b80a           1.0
#
# [32951 rows x 1 columns]

# %% [markdown]
# #### average rating by category

# %%
cust_order_final.loc[:, ['product_category_name', 'review_score']].groupby('product_category_name').mean().sort_values(by = 'review_score', ascending = False)
# Out:
#                                        review_score
# product_category_name
# Books_Imported                             4.664000
# Cds_Dvds_Musicals                          4.600000
# Fashion_Childrens_Clothes                  4.500000
# Small_Appliances_Home_Oven_And_Coffee      4.450000
# Books_General_Interest                     4.444126
# ...                                             ...
# La_Cuisine                                 3.500000
# Fashion_Male_Clothing                      3.469565
# Diapers_And_Hygiene                        3.304348
# Home_Comfort_2                             3.300000
# Security_And_Services                      2.500000
#
# [71 rows x 1 columns]

# %% [markdown]
# #### average rating by month

# %%
cust_order_final.loc[:, ['Month', 'review_score']].groupby('Month').mean()
# Out:
#        review_score
# Month
# 01         3.934677
# 02         3.755536
# 03         3.776608
# 04         4.049521
# 05         4.106060
# 06         4.147448
# 07         4.162123
# 08         4.205031
# 09         4.090425
# 10         3.970492
# 11         3.825431
# 12         3.941055
